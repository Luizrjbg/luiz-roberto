# %%
andar=21
while (andar>1):
  andar= andar-1
  if (andar == 13):
    continue
  print(andar,"º andar" )

# %%
for andar in range (0,20,1):
  andar= andar +1
  if (andar == 13):
    continue
  print (andar,'º andar')

# %%
for andar in range (20):
  andar= andar +1
  if (andar == 13):
    continue
  print (andar,'º andar')
